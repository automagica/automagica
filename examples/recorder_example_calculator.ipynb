# %% [markdown]
# # Recorder example with Windows Calculator
#
# This example shows how to use the Automagica recorder functionality to easily find elements on a screen. This eliminates the tedious task of finding the techinical identifier of elements.
#
# In addition, sometimes working with the recorder is the only way to reliably find buttons and elements, for example when working with a virtualized desktop such as Citrix, TeamViewer,
#
# In this example we will automate the Windows Calculator by identifying the buttons using the Automagica recorder, clicking and finally reading the output with Automagica vision (ocr).

# %% [markdown]
# ## Starting the recorder
#
# The recorder can be opened by either pressing the Recorder button in the Automagica Lab, by running 'automagica recorder' in a Windows console on a system with Automagica installed, or by running the following commands in a Python console:

# %%
from automagica import *

recorder()

# %% [markdown]
# ## Setting your target
#
# The automagica recorder relies on vision to identify elements on the screen. It uses a smart algorithm to find the best match which makes it robust to minor changes in the UI.
#
# For starters, after choosing the preferred action in the recorder you have to identify your target by dragging a box around the element. Make sure you only select the element you want to target, including irrelevant changing elements in the target could cause a mismatch.

# %% [markdown]
# ## Anchors
#
# When your target is subject to change it is a good idea to pick an anchor. An anchor is an element that does not change in appearance and does not change in relative position to your target.
#
# For example, in browser automation when clicking on the first Google result, this result is subject to change depending on what you searched. However, there are a lot of elements that are static relative to the first result:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Automating the Calculator
#
# For this example we will add 1 + 1 and read the output.
#
# Here we have already used the recorder to identify the buttons and find the elements, you can view the results at the following links:
#
# '1' button on the Calculator:
# https://automagica.id/qf41
#
# '+' button on the Calculator:
# https://automagica.id/OfJ5
#
# Result window on the Calculator:
# https://automagica.id/1HXT

# %% [markdown]
# ### Click on the '1'

# %%
# Make sure you imported Automagica
from automagica import *

click("qf41")

# %% [markdown]
# ### Click on the '+'

# %%
click("Fxtq")

# %% [markdown]
# ### Click on '1' again

# %%
click("qf41")

# %% [markdown]
# ### Click on '+' once more to calculate the answer

# %%
click("Fxtq")

# %% [markdown]
# ### Read the outcome

# %%
read_text("PYwk")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-7b5252981e20> in <module>
# ----> 1 read_text("1HXT")
#
# c:\users\tvt\repositories\automagica\automagica\utilities.py in wrapper(*args, **kwargs)
#      15         logging.info("Automagica (activity): {}".format(name))
#      16         telemetry(func)
# ---> 17         return func(*args, **kwargs)
#      18
#      19     return wrapper
#
# c:\users\tvt\repositories\automagica\automagica\activities.py in read_text(element_id, delay)
#   10006     sleep(delay)  # Default delay
#   10007
# > 10008     location = detect_vision(element_id, detect_target=False)
#   10009
#   10010     screenshot = capture_screen()
#
# c:\users\tvt\repositories\automagica\automagica\activities.py in detect_vision(element_id, detect_target)
#    9845
#    9846     if data.get("error"):
# -> 9847         raise Exception(data["error"])
# ...
